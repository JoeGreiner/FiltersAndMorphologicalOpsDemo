# %% [markdown]
# # Binary Morphological Operations
#
# Binary morphological operations (morphology == the study of the forms of things) are very handy operations on binary images, such as the thresholded mask we generated before. While simple, the chaining of different operations can be powerful.
#
#
# ## Opening and Closing
#
# ---
#
# ## <font color='red'>TASK:</font>
# Run the following cell pressing the 'Run' Button in the taskbar above or pressing Shift+Enter. Explore in the following applet the binary operations <b>Opening</b> and <b>Closing</b> What do they do? What could they be useful for?
#
#
# ---

# %%
# %matplotlib notebook
from helpers.morphology import OpenCloseWidget, DilateErodeWidget, Drawer
OpenCloseWidget()
# Out:
# ...
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ---
#
# ## <font color='red'>TASK:</font>
# The following Applet adds two very basic morpholgical operations: <b>Dilation</b> and <b>Erosion</b>. Explore their function.
#
# How do you have to sequence them to achieve the same function as <b>Opening</b> and <b>Closing</b>?
#
# ---

# %%
DilateErodeWidget()
# Out:
# ...
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ---
#
# ## <font color='red'>TASK:</font>
# Additionally to the four morphological operations, the next application allows you to draw inside the image. Left mouse click will paint, right mouse click will erase at the pointer location.
#
# Explore the widgets, try to draw 1–2 examples where the previously introduced operations could be useful.
#
# ---

# %%
drawer = Drawer()
# Out:
# ...
# <img src="data:image/png;base64,..." width="500">
